# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "q=" + city + "&units=Imperial&APPID=" + weather_api_key

    # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of 50 in Set {set_count} | {city_weather['name']}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_name = city_weather["name"]
        print(f"Processing Record {record_count} of 50 in Set {set_count} | {city_name}")
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date,})

# If an error is experienced, skip the city.
    except:
        print(f"{city_name} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2 of 50 in Set 1 | George Town
# Processing Record 3 of 50 in Set 1 | Tasiilaq
# Processing Record 4 of 50 in Set 1 | Vaini
# Vaini not found. Skipping...
# Processing Record 6 of 50 in Set 1 | Mahébourg
# Processing Record 7 of 50 in Set 1 | Saint Paul Harbor
# Saint Paul Harbor not found. Skipping...
# Processing Record 9 of 50 in Set 1 | Kabalo
# Kabalo not found. Skipping...
# Processing Record 11 of 50 in Set 1 | Rikitea
# Processing Record 12 of 50 in Set 1 | Qaanaaq
# Processing Record 13 of 50 in Set 1 | Jiwani
# Processing Record 14 of 50 in Set 1 | Uren'
# Processing Record 15 of 50 in Set 1 | Puerto Ayora
# Puerto Ayora not found. Skipping...
# Processing Record 17 of 50 in Set 1 | Sampit
# Processing Record 18 of 50 in Set 1 | Butaritari
# Processing Record 19 of 50 in Set 1 | Hilo
# Processing Record 20 of 50 in Set 1 | Port Alfred
# Processing Record 21 of 50 in Set 1 | Kruisfontein
# Processing Record 22 of 50 in Set 1 | Senador José Porfírio
# Processing Record 23 of 50 in Set 1 | Ghanzi
# Processing Record 24 of 50 in Set 1 | Upernavik
# Processing Record 25 of 50 in Set 1 | Ovalle
# Processing Record 26 of 50 in Set 1 | Busselton
# Processing Record 27 of 50 in Set 1 | Kiunga
# Processing Record 28 of 50 in Set 1 | Kirakira
# Processing Record 29 of 50 in Set 1 | Bluff
# Processing Record 30 of 50 in Set 1 | Punta Arenas
# Processing Record 31 of 50 in Set 1 | Mataura
# Processing Record 32 of 50 in Set 1 | Hong Kong
# Processing Record 33 of 50 in Set 1 | Kaitangata
# Processing Record 34 of 50 in Set 1 | Haines Junction
# Processing Record 35 of 50 in Set 1 | Nieuw Amsterdam
# Processing Record 36 of 50 in Set 1 | Malanje
# Processing Record 37 of 50 in Set 1 | Morant Bay
# Processing Record 38 of 50 in Set 1 | Cape Town
# Processing Record 39 of 50 in Set 1 | Barrow
# Processing Record 40 of 50 in Set 1 | Serov
# Processing Record 41 of 50 in Set 1 | Avarua
# Processing Record 42 of 50 in Set 1 | Leningradskiy
# Processing Record 43 of 50 in Set 1 | Broken Hill
# Processing Record 44 of 50 in Set 1 | Ambovombe
# Processing Record 45 of 50 in Set 1 | Los Llanos de Aridane
# Processing Record 46 of 50 in Set 1 | Provideniya
# Processing Record 47 of 50 in Set 1 | Omboué
# Processing Record 48 of 50 in Set 1 | Kapaa
# Processing Record 49 of 50 in Set 1 | Bethel
# Processing Record 50 of 50 in Set 1 | Saldanha
# Processing Record 51 of 50 in Set 1 | Vao
# Processing Record 2 of 50 in Set 2 | Gushikawa
# Processing Record 3 of 50 in Set 2 | Hermanus
# Hermanus not found. Skipping...
# Processing Record 5 of 50 in Set 2 | Gambēla
# Processing Record 6 of 50 in Set 2 | Banyo
# Processing Record 7 of 50 in Set 2 | São Gabriel da Cachoeira
# Processing Record 8 of 50 in Set 2 | Chiang Khong
# Processing Record 9 of 50 in Set 2 | Hasaki
# Processing Record 10 of 50 in Set 2 | Eureka
# Processing Record 11 of 50 in Set 2 | Cândido Mendes
# Processing Record 12 of 50 in Set 2 | Lorengau
# Lorengau not found. Skipping...
# Processing Record 14 of 50 in Set 2 | Kavieng
# Processing Record 15 of 50 in Set 2 | Deputatsky
# Processing Record 16 of 50 in Set 2 | Narsaq
# Processing Record 17 of 50 in Set 2 | Cap Malheureux
# Processing Record 18 of 50 in Set 2 | Severo-Kuril'sk
# Processing Record 19 of 50 in Set 2 | Sørland
# Processing Record 20 of 50 in Set 2 | Husavik
# Processing Record 21 of 50 in Set 2 | Tuktoyaktuk
# Processing Record 22 of 50 in Set 2 | Newport
# Processing Record 23 of 50 in Set 2 | Ashland
# Processing Record 24 of 50 in Set 2 | Beringovskiy
# Processing Record 25 of 50 in Set 2 | Yulara
# Processing Record 26 of 50 in Set 2 | Chui
# Processing Record 27 of 50 in Set 2 | Marion
# Processing Record 28 of 50 in Set 2 | New Norfolk
# Processing Record 29 of 50 in Set 2 | Abhā
# Processing Record 30 of 50 in Set 2 | Tiksi
# Processing Record 31 of 50 in Set 2 | Carnarvon
# Processing Record 32 of 50 in Set 2 | São Filipe
# Processing Record 33 of 50 in Set 2 | Laguna
# Processing Record 34 of 50 in Set 2 | Hobart
# Processing Record 35 of 50 in Set 2 | Ushuaia
# Processing Record 36 of 50 in Set 2 | Atuona
# Processing Record 37 of 50 in Set 2 | Neiafu
# Processing Record 38 of 50 in Set 2 | Ribeira Grande
# Processing Record 39 of 50 in Set 2 | Turochak
# Turochak not found. Skipping...
# Processing Record 41 of 50 in Set 2 | Broome
# Processing Record 42 of 50 in Set 2 | Buriti Alegre
# Processing Record 43 of 50 in Set 2 | Sur
# Processing Record 44 of 50 in Set 2 | Terråk
# Processing Record 45 of 50 in Set 2 | Dikson
# Processing Record 46 of 50 in Set 2 | Saint-François
# Saint-François not found. Skipping...
# Saint-François not found. Skipping...
# Processing Record 49 of 50 in Set 2 | Lompoc
# Processing Record 50 of 50 in Set 2 | Talnakh
# Processing Record 51 of 50 in Set 2 | Grand Baie
# Processing Record 2 of 50 in Set 3 | Albany
# Processing Record 3 of 50 in Set 3 | Port Hedland
# Processing Record 4 of 50 in Set 3 | Sakakah
# Processing Record 5 of 50 in Set 3 | Aklavik
# Processing Record 6 of 50 in Set 3 | Gobabis
# Processing Record 7 of 50 in Set 3 | Bredasdorp
# Processing Record 8 of 50 in Set 3 | Tilichiki
# Processing Record 9 of 50 in Set 3 | Isabela
# Processing Record 10 of 50 in Set 3 | Faya
# Processing Record 11 of 50 in Set 3 | Makkah al Mukarramah
# Processing Record 12 of 50 in Set 3 | Hofn
# Hofn not found. Skipping...
# Processing Record 14 of 50 in Set 3 | Wiarton
# Processing Record 15 of 50 in Set 3 | Norman Wells
# Processing Record 16 of 50 in Set 3 | Wanning
# Processing Record 17 of 50 in Set 3 | Maputo
# Processing Record 18 of 50 in Set 3 | Aurillac
# Processing Record 19 of 50 in Set 3 | Chicama
# Chicama not found. Skipping...
# Processing Record 21 of 50 in Set 3 | East London
# Processing Record 22 of 50 in Set 3 | Acapulco de Juárez
# Processing Record 23 of 50 in Set 3 | Karratha
# Processing Record 24 of 50 in Set 3 | Castro
# Processing Record 25 of 50 in Set 3 | Lebu
# Processing Record 26 of 50 in Set 3 | Cidreira
# Processing Record 27 of 50 in Set 3 | Airai
# Processing Record 28 of 50 in Set 3 | Pop
# Processing Record 29 of 50 in Set 3 | Loreto
# Processing Record 30 of 50 in Set 3 | Mar del Plata
# Mar del Plata not found. Skipping...
# Processing Record 32 of 50 in Set 3 | Longyearbyen
# Processing Record 33 of 50 in Set 3 | Yellowknife
# Processing Record 34 of 50 in Set 3 | Tuatapere
# Processing Record 35 of 50 in Set 3 | Kotel'nich
# Processing Record 36 of 50 in Set 3 | Namatanai
# Processing Record 37 of 50 in Set 3 | Batagay-Alyta
# Processing Record 38 of 50 in Set 3 | Chokurdakh
# Processing Record 39 of 50 in Set 3 | Itarema
# Processing Record 40 of 50 in Set 3 | Palmer
# Processing Record 41 of 50 in Set 3 | Souillac
# Processing Record 42 of 50 in Set 3 | Sainte-Marie
# Processing Record 43 of 50 in Set 3 | Guiren
# Processing Record 44 of 50 in Set 3 | Roald
# Roald not found. Skipping...
# Processing Record 46 of 50 in Set 3 | Champerico
# Champerico not found. Skipping...
# Processing Record 48 of 50 in Set 3 | São Raimundo das Mangabeiras
# Processing Record 49 of 50 in Set 3 | Saint-Philippe
# Processing Record 50 of 50 in Set 3 | Henties Bay
# Henties Bay not found. Skipping...
# Processing Record 2 of 50 in Set 4 | Wasilla
# Wasilla not found. Skipping...
# Processing Record 4 of 50 in Set 4 | Cherskiy
# Processing Record 5 of 50 in Set 4 | Hithadhoo
# Processing Record 6 of 50 in Set 4 | Todos Santos
# Processing Record 7 of 50 in Set 4 | Alofi
# Processing Record 8 of 50 in Set 4 | Zhifang
# Processing Record 9 of 50 in Set 4 | Sibiti
# Processing Record 10 of 50 in Set 4 | Kristiansund
# Processing Record 11 of 50 in Set 4 | Tambopata
# Processing Record 12 of 50 in Set 4 | Erzin
# Processing Record 13 of 50 in Set 4 | Mossamedes
# Processing Record 14 of 50 in Set 4 | Gigmoto
# Processing Record 15 of 50 in Set 4 | La Ronge
# Processing Record 16 of 50 in Set 4 | Qui Nhon
# Processing Record 17 of 50 in Set 4 | Hay River
# Processing Record 18 of 50 in Set 4 | Leme
# Processing Record 19 of 50 in Set 4 | Lumphat
# Processing Record 20 of 50 in Set 4 | Sandpoint
# Processing Record 21 of 50 in Set 4 | Quesnel
# Processing Record 22 of 50 in Set 4 | Monrovia
# Processing Record 23 of 50 in Set 4 | Lerwick
# Processing Record 24 of 50 in Set 4 | Sinnamary
# Sinnamary not found. Skipping...
# Processing Record 26 of 50 in Set 4 | Thompson
# Processing Record 27 of 50 in Set 4 | Vestmannaeyjar
# Processing Record 28 of 50 in Set 4 | Lasem
# Processing Record 29 of 50 in Set 4 | Yerbogachën
# Processing Record 30 of 50 in Set 4 | Saint-Augustin
# Processing Record 31 of 50 in Set 4 | Touros
# Processing Record 32 of 50 in Set 4 | Flinders
# Processing Record 33 of 50 in Set 4 | Portland
# Portland not found. Skipping...
# Processing Record 35 of 50 in Set 4 | Naryan-Mar
# Processing Record 36 of 50 in Set 4 | Luau
# Processing Record 37 of 50 in Set 4 | Port Elizabeth
# Processing Record 38 of 50 in Set 4 | Ponta do Sol
# Processing Record 39 of 50 in Set 4 | Vaitape
# Processing Record 40 of 50 in Set 4 | Fortuna
# Fortuna not found. Skipping...
# Processing Record 42 of 50 in Set 4 | Fairbanks
# Processing Record 43 of 50 in Set 4 | Jamestown
# Processing Record 44 of 50 in Set 4 | Opuwo
# Processing Record 45 of 50 in Set 4 | Olafsvik
# Processing Record 46 of 50 in Set 4 | Nantucket
# Processing Record 47 of 50 in Set 4 | Chapais
# Processing Record 48 of 50 in Set 4 | Pacific Grove
# Processing Record 49 of 50 in Set 4 | Pampa
# Processing Record 50 of 50 in Set 4 | Sioux Lookout
# Processing Record 51 of 50 in Set 4 | Savinka
# Processing Record 2 of 50 in Set 5 | Scarborough
# Processing Record 3 of 50 in Set 5 | Yar-Sale
# Processing Record 4 of 50 in Set 5 | Athabasca
# Processing Record 5 of 50 in Set 5 | Charters Towers
# Processing Record 6 of 50 in Set 5 | Heraclea
# Processing Record 7 of 50 in Set 5 | Sri Aman
# Sri Aman not found. Skipping...
# Processing Record 9 of 50 in Set 5 | Sitka
# Processing Record 10 of 50 in Set 5 | Constitución
# Processing Record 11 of 50 in Set 5 | Marrakesh
# Processing Record 12 of 50 in Set 5 | Ocós
# Processing Record 13 of 50 in Set 5 | San Quintín
# Processing Record 14 of 50 in Set 5 | Nadym
# Processing Record 15 of 50 in Set 5 | Bathsheba
# Processing Record 16 of 50 in Set 5 | Nemuro
# Processing Record 17 of 50 in Set 5 | Arraial do Cabo
# Processing Record 18 of 50 in Set 5 | Bonavista
# Processing Record 19 of 50 in Set 5 | Vetas
# Processing Record 20 of 50 in Set 5 | Santa Cruz de la Sierra
# Processing Record 21 of 50 in Set 5 | Chlórakas
# Processing Record 22 of 50 in Set 5 | Khatanga
# Processing Record 23 of 50 in Set 5 | Tucumã
# Processing Record 24 of 50 in Set 5 | Okhotsk
# Processing Record 25 of 50 in Set 5 | Magadan
# Processing Record 26 of 50 in Set 5 | Tari
# Processing Record 27 of 50 in Set 5 | Tura
# Processing Record 28 of 50 in Set 5 | Nanortalik
# Processing Record 29 of 50 in Set 5 | Zhigansk
# Zhigansk not found. Skipping...
# Processing Record 31 of 50 in Set 5 | Pokhara
# Processing Record 32 of 50 in Set 5 | Vuktyl
# Processing Record 33 of 50 in Set 5 | Keminmaa
# Processing Record 34 of 50 in Set 5 | Lugovoy
# Processing Record 35 of 50 in Set 5 | Pevek
# Processing Record 36 of 50 in Set 5 | Nānākuli
# Processing Record 37 of 50 in Set 5 | Turukhansk
# Processing Record 38 of 50 in Set 5 | Esso
# Processing Record 39 of 50 in Set 5 | Sorong
# Processing Record 40 of 50 in Set 5 | Menongue
# Processing Record 41 of 50 in Set 5 | Fort Nelson
# Processing Record 42 of 50 in Set 5 | Port-Gentil
# Processing Record 43 of 50 in Set 5 | Zigong
# Processing Record 44 of 50 in Set 5 | Mayskiy
# Processing Record 45 of 50 in Set 5 | Hailar
# Processing Record 46 of 50 in Set 5 | Ust'-Ilimsk
# Processing Record 47 of 50 in Set 5 | Glasgow
# Processing Record 48 of 50 in Set 5 | Faanui
# Processing Record 49 of 50 in Set 5 | Vila Franca do Campo
# Processing Record 50 of 50 in Set 5 | Luganville
# Processing Record 51 of 50 in Set 5 | Nyaunglebin
# Processing Record 2 of 50 in Set 6 | Shimoda
# Processing Record 3 of 50 in Set 6 | Lufilufi
# Processing Record 4 of 50 in Set 6 | Apac
# Processing Record 5 of 50 in Set 6 | Katsuura
# Processing Record 6 of 50 in Set 6 | Saint George
# Processing Record 7 of 50 in Set 6 | Tignère
# Processing Record 8 of 50 in Set 6 | Vung Tau
# Processing Record 9 of 50 in Set 6 | Taoudenni
# Processing Record 10 of 50 in Set 6 | Vardø
# Processing Record 11 of 50 in Set 6 | Tromsø
# Processing Record 12 of 50 in Set 6 | Lishui
# Processing Record 13 of 50 in Set 6 | Daşoguz
# Processing Record 14 of 50 in Set 6 | Bilibino
# Bilibino not found. Skipping...
# Processing Record 16 of 50 in Set 6 | Maceió
# Processing Record 17 of 50 in Set 6 | Dunedin
# Processing Record 18 of 50 in Set 6 | Nikolskoye
# Processing Record 19 of 50 in Set 6 | Prigorodnyy
# Processing Record 20 of 50 in Set 6 | Nizhniy Kuranakh
# Processing Record 21 of 50 in Set 6 | Batemans Bay
# Processing Record 22 of 50 in Set 6 | Rovaniemi
# Processing Record 23 of 50 in Set 6 | Serebryansk
# Processing Record 24 of 50 in Set 6 | Lékoni
# Processing Record 25 of 50 in Set 6 | Suntar
# Processing Record 26 of 50 in Set 6 | Vila do Maio
# Processing Record 27 of 50 in Set 6 | North Vanlaiphai
# Processing Record 28 of 50 in Set 6 | Koslan
# Processing Record 29 of 50 in Set 6 | Hatillo
# Processing Record 30 of 50 in Set 6 | Vertou
# Processing Record 31 of 50 in Set 6 | Burnie
# Processing Record 32 of 50 in Set 6 | ‘Āhuimanu
# Processing Record 33 of 50 in Set 6 | Port Lincoln
# Processing Record 34 of 50 in Set 6 | Dubai
# Processing Record 35 of 50 in Set 6 | Srednekolymsk
# Processing Record 36 of 50 in Set 6 | Longonjo
# Processing Record 37 of 50 in Set 6 | Rawson
# Processing Record 38 of 50 in Set 6 | Fasa
# Processing Record 39 of 50 in Set 6 | Reinosa
# Processing Record 40 of 50 in Set 6 | Minnedosa
# Minnedosa not found. Skipping...
# Minnedosa not found. Skipping...
# Processing Record 43 of 50 in Set 6 | Ouadda
# Processing Record 44 of 50 in Set 6 | San Rafael
# Processing Record 45 of 50 in Set 6 | Janakkala
# Processing Record 46 of 50 in Set 6 | São João da Barra
# Processing Record 47 of 50 in Set 6 | Kyren
# Processing Record 48 of 50 in Set 6 | Zinder
# Processing Record 49 of 50 in Set 6 | Colesberg
# Processing Record 50 of 50 in Set 6 | Shirokiy
# Processing Record 51 of 50 in Set 6 | Esim
# Processing Record 2 of 50 in Set 7 | Casablanca
# Processing Record 3 of 50 in Set 7 | Hollins
# Processing Record 4 of 50 in Set 7 | Mount Gambier
# Processing Record 5 of 50 in Set 7 | Avera
# Processing Record 6 of 50 in Set 7 | High Level
# Processing Record 7 of 50 in Set 7 | Wonthaggi
# Processing Record 8 of 50 in Set 7 | Almeirim
# Processing Record 9 of 50 in Set 7 | Gryazovets
# Processing Record 10 of 50 in Set 7 | Norrtälje
# Processing Record 11 of 50 in Set 7 | Bariloche
# Bariloche not found. Skipping...
# Processing Record 13 of 50 in Set 7 | Mikkeli
# Processing Record 14 of 50 in Set 7 | Mount Isa
# Processing Record 15 of 50 in Set 7 | Dingle
# Processing Record 16 of 50 in Set 7 | Caravelas
# Caravelas not found. Skipping...
# Processing Record 18 of 50 in Set 7 | Khani
# Processing Record 19 of 50 in Set 7 | Sisauli
# Processing Record 20 of 50 in Set 7 | Yeppoon
# Processing Record 21 of 50 in Set 7 | Pullman
# Processing Record 22 of 50 in Set 7 | Pilar
# Processing Record 23 of 50 in Set 7 | Michigan City
# Processing Record 24 of 50 in Set 7 | Richards Bay
# Processing Record 25 of 50 in Set 7 | Pudozh
# Pudozh not found. Skipping...
# Processing Record 27 of 50 in Set 7 | San Patricio
# Processing Record 28 of 50 in Set 7 | Fukuechō
# Processing Record 29 of 50 in Set 7 | Isangel
# Processing Record 30 of 50 in Set 7 | Korla
# Processing Record 31 of 50 in Set 7 | Ōarai
# Processing Record 32 of 50 in Set 7 | Coquimbo
# Processing Record 33 of 50 in Set 7 | Dalby
# Processing Record 34 of 50 in Set 7 | Sydney
# Processing Record 35 of 50 in Set 7 | Lüderitz
# Processing Record 36 of 50 in Set 7 | George
# Processing Record 37 of 50 in Set 7 | Dzerzhinsk
# Processing Record 38 of 50 in Set 7 | Nome
# Processing Record 39 of 50 in Set 7 | Piranshahr
# Processing Record 40 of 50 in Set 7 | Coyhaique
# Processing Record 41 of 50 in Set 7 | Soe
# Processing Record 42 of 50 in Set 7 | Neuquén
# Processing Record 43 of 50 in Set 7 | İdil
# Processing Record 44 of 50 in Set 7 | Tabat
# Processing Record 45 of 50 in Set 7 | Tarakan
# Processing Record 46 of 50 in Set 7 | Stillwater
# Processing Record 47 of 50 in Set 7 | Geraldton
# Processing Record 48 of 50 in Set 7 | Bonfim
# Processing Record 49 of 50 in Set 7 | Dolinsk
# Processing Record 50 of 50 in Set 7 | Torbay
# Processing Record 51 of 50 in Set 7 | Teguise
# Processing Record 2 of 50 in Set 8 | Vostok
# Processing Record 3 of 50 in Set 8 | Bambous Virieux
# Processing Record 4 of 50 in Set 8 | Birao
# Processing Record 5 of 50 in Set 8 | Lethem
# Processing Record 6 of 50 in Set 8 | Yumen
# Processing Record 7 of 50 in Set 8 | Glendive
# Processing Record 8 of 50 in Set 8 | Kushmurun
# Processing Record 9 of 50 in Set 8 | Labuhan
# Processing Record 10 of 50 in Set 8 | Launceston
# Processing Record 11 of 50 in Set 8 | Tacoronte
# Processing Record 12 of 50 in Set 8 | Tessalit
# Processing Record 13 of 50 in Set 8 | Chabahar
# Processing Record 14 of 50 in Set 8 | Kumul
# Kumul not found. Skipping...
# Processing Record 16 of 50 in Set 8 | Tiznit Province
# Processing Record 17 of 50 in Set 8 | Padampur
# Padampur not found. Skipping...
# Processing Record 19 of 50 in Set 8 | Mumbwa
# Processing Record 20 of 50 in Set 8 | Wahiawā
# Processing Record 21 of 50 in Set 8 | Yicheng
# Processing Record 22 of 50 in Set 8 | Brigantine
# Processing Record 23 of 50 in Set 8 | Mareeba
# Processing Record 24 of 50 in Set 8 | Half Moon Bay
# Processing Record 25 of 50 in Set 8 | Ostrovnoy
# Processing Record 26 of 50 in Set 8 | Itupiranga
# Processing Record 27 of 50 in Set 8 | Likasi
# Processing Record 28 of 50 in Set 8 | Kapuskasing
# Kapuskasing not found. Skipping...
# Processing Record 30 of 50 in Set 8 | Vauvert
# Processing Record 31 of 50 in Set 8 | Ust-Tsilma
# Processing Record 32 of 50 in Set 8 | Gouré
# Processing Record 33 of 50 in Set 8 | Challans
# Processing Record 34 of 50 in Set 8 | Pāndoh
# Processing Record 35 of 50 in Set 8 | Ulkan
# Processing Record 36 of 50 in Set 8 | Aban
# Processing Record 37 of 50 in Set 8 | Chimbote
# Chimbote not found. Skipping...
# Processing Record 39 of 50 in Set 8 | Buraidah
# Processing Record 40 of 50 in Set 8 | Lake Shasta
# Processing Record 41 of 50 in Set 8 | Saskylakh
# Processing Record 42 of 50 in Set 8 | Mezhdurechenskiy
# Processing Record 43 of 50 in Set 8 | Verāval
# Processing Record 44 of 50 in Set 8 | Saryg-Sep
# Processing Record 45 of 50 in Set 8 | Altamira
# Processing Record 46 of 50 in Set 8 | Carauari
# Carauari not found. Skipping...
# Processing Record 48 of 50 in Set 8 | Hambantota
# Processing Record 49 of 50 in Set 8 | Kavaratti
# Processing Record 50 of 50 in Set 8 | Chulym
# Processing Record 51 of 50 in Set 8 | Waldoboro
# Processing Record 2 of 50 in Set 9 | Siquijor
# Processing Record 3 of 50 in Set 9 | Nioro
# Processing Record 4 of 50 in Set 9 | Fort Saint James
# Processing Record 5 of 50 in Set 9 | Xinyu
# Processing Record 6 of 50 in Set 9 | Esperance
# Processing Record 7 of 50 in Set 9 | Arlit
# Processing Record 8 of 50 in Set 9 | Udachny
# Processing Record 9 of 50 in Set 9 | Jumla
# Processing Record 10 of 50 in Set 9 | Asău
# Asău not found. Skipping...
# Processing Record 12 of 50 in Set 9 | Yangshan
# Processing Record 13 of 50 in Set 9 | Rock Springs
# Processing Record 14 of 50 in Set 9 | Council Bluffs
# Processing Record 15 of 50 in Set 9 | Paka
# Processing Record 16 of 50 in Set 9 | Port Hardy
# Processing Record 17 of 50 in Set 9 | Karpathos
# Processing Record 18 of 50 in Set 9 | Leh
# Processing Record 19 of 50 in Set 9 | Thinadhoo
# Processing Record 20 of 50 in Set 9 | Honiara
# Processing Record 21 of 50 in Set 9 | Alice Springs
# Processing Record 22 of 50 in Set 9 | Sola
# Processing Record 23 of 50 in Set 9 | Belmonte
# Processing Record 24 of 50 in Set 9 | Matagami
# Processing Record 25 of 50 in Set 9 | Abu Samrah
# Processing Record 26 of 50 in Set 9 | Manzhouli
# Processing Record 27 of 50 in Set 9 | Grafton
# Processing Record 28 of 50 in Set 9 | Itoman
# Processing Record 29 of 50 in Set 9 | Quelimane
# Processing Record 30 of 50 in Set 9 | Grand-Santi
# Processing Record 31 of 50 in Set 9 | Kisangani
# Processing Record 32 of 50 in Set 9 | Evans
# Processing Record 33 of 50 in Set 9 | Ilulissat
# Processing Record 34 of 50 in Set 9 | Takoradze
# Processing Record 35 of 50 in Set 9 | Yerofey Pavlovich
# Processing Record 36 of 50 in Set 9 | Mbanza-Ngungu
# Processing Record 37 of 50 in Set 9 | Lázaro Cárdenas
# Processing Record 38 of 50 in Set 9 | Kibala
# Processing Record 39 of 50 in Set 9 | Lavrentiya
# Processing Record 40 of 50 in Set 9 | Varhaug
# Processing Record 41 of 50 in Set 9 | Saint-Joseph
# Processing Record 42 of 50 in Set 9 | Kushima
# Kushima not found. Skipping...
# Processing Record 44 of 50 in Set 9 | Praia
# Processing Record 45 of 50 in Set 9 | Umm Kaddadah
# Processing Record 46 of 50 in Set 9 | Aksarka
# Processing Record 47 of 50 in Set 9 | Yamada
# Processing Record 48 of 50 in Set 9 | Tandaltī
# Processing Record 49 of 50 in Set 9 | São Félix do Xingu
# Processing Record 50 of 50 in Set 9 | Balkhash
# Processing Record 51 of 50 in Set 9 | Malakal
# Processing Record 2 of 50 in Set 10 | Makakilo City
# Processing Record 3 of 50 in Set 10 | Paamiut
# Processing Record 4 of 50 in Set 10 | San Cristobal
# Processing Record 5 of 50 in Set 10 | Olavarría
# Processing Record 6 of 50 in Set 10 | Morondava
# Processing Record 7 of 50 in Set 10 | Marau
# Processing Record 8 of 50 in Set 10 | Cornereva
# Processing Record 9 of 50 in Set 10 | Elko
# Processing Record 10 of 50 in Set 10 | Thessalon
# Processing Record 11 of 50 in Set 10 | Santa Vitória do Palmar
# Processing Record 12 of 50 in Set 10 | Clyde River
# Processing Record 13 of 50 in Set 10 | Krasnosel'kup
# Processing Record 14 of 50 in Set 10 | Rivers
# Processing Record 15 of 50 in Set 10 | Maţāy
# Processing Record 16 of 50 in Set 10 | Troitsko-Pechorsk
# Processing Record 17 of 50 in Set 10 | Ballina
# Ballina not found. Skipping...
# Processing Record 19 of 50 in Set 10 | Carballo
# Carballo not found. Skipping...
# Processing Record 21 of 50 in Set 10 | Iqaluit
# Processing Record 22 of 50 in Set 10 | Żurrieq
# Processing Record 23 of 50 in Set 10 | Cho Dok
# Processing Record 24 of 50 in Set 10 | Collipulli
# Processing Record 25 of 50 in Set 10 | Monroe
# Processing Record 26 of 50 in Set 10 | Chara
# Processing Record 27 of 50 in Set 10 | Kamenskiy
# Processing Record 28 of 50 in Set 10 | Bengkulu
# Processing Record 29 of 50 in Set 10 | Conde
# Processing Record 30 of 50 in Set 10 | Havelock
# Processing Record 31 of 50 in Set 10 | Petropavlovsk-Kamchatskiy
# Processing Record 32 of 50 in Set 10 | Narathiwat
# Narathiwat not found. Skipping...
# Processing Record 34 of 50 in Set 10 | Havøysund
# Processing Record 35 of 50 in Set 10 | Tottori-shi
# Processing Record 36 of 50 in Set 10 | Tianpeng
# Processing Record 37 of 50 in Set 10 | Cabo San Lucas
# Processing Record 38 of 50 in Set 10 | Erbil
# Processing Record 39 of 50 in Set 10 | Loukhi
# Loukhi not found. Skipping...
# Processing Record 41 of 50 in Set 10 | Antofagasta
# Processing Record 42 of 50 in Set 10 | Podporozh'ye
# Processing Record 43 of 50 in Set 10 | Podor
# Processing Record 44 of 50 in Set 10 | Anaconda
# Processing Record 45 of 50 in Set 10 | Puerto del Rosario
# Processing Record 46 of 50 in Set 10 | Raudeberg
# Processing Record 47 of 50 in Set 10 | Tokur
# Processing Record 48 of 50 in Set 10 | Aasiaat
# Processing Record 49 of 50 in Set 10 | Pozo Colorado
# Processing Record 50 of 50 in Set 10 | Port Macquarie
# Processing Record 51 of 50 in Set 10 | Sabang
# Processing Record 2 of 50 in Set 11 | Santiago del Estero
# Processing Record 3 of 50 in Set 11 | Lata
# Processing Record 4 of 50 in Set 11 | Pierre
# Processing Record 5 of 50 in Set 11 | Guerrero Negro
# Processing Record 6 of 50 in Set 11 | Snezhnogorsk
# Processing Record 7 of 50 in Set 11 | Borogontsy
# Processing Record 8 of 50 in Set 11 | Departamento de Maldonado
# Processing Record 9 of 50 in Set 11 | Aginskoye
# Processing Record 10 of 50 in Set 11 | Flin Flon
# Processing Record 11 of 50 in Set 11 | Châtellerault
# Processing Record 12 of 50 in Set 11 | Nassau
# Processing Record 13 of 50 in Set 11 | Rawdon
# Processing Record 14 of 50 in Set 11 | Pisz
# Processing Record 15 of 50 in Set 11 | Cabedelo
# Processing Record 16 of 50 in Set 11 | Mollendo
# Mollendo not found. Skipping...
# Processing Record 18 of 50 in Set 11 | Iara
# Processing Record 19 of 50 in Set 11 | Baykit
# Processing Record 20 of 50 in Set 11 | Kailua
# Processing Record 21 of 50 in Set 11 | Alugan
# Processing Record 22 of 50 in Set 11 | Bandarbeyla
# Processing Record 23 of 50 in Set 11 | Chingirlau
# Processing Record 24 of 50 in Set 11 | Sironj
# Processing Record 25 of 50 in Set 11 | Vila Velha
# Vila Velha not found. Skipping...
# Processing Record 27 of 50 in Set 11 | Margate
# Processing Record 28 of 50 in Set 11 | Alekseyevka
# Processing Record 29 of 50 in Set 11 | Mauá
# Processing Record 30 of 50 in Set 11 | Te Anau
# Processing Record 31 of 50 in Set 11 | Arkhangelsk
# Processing Record 32 of 50 in Set 11 | Mt. Pleasant
# Processing Record 33 of 50 in Set 11 | Ust-Kuyga
# Processing Record 34 of 50 in Set 11 | Verkhoyansk
# Processing Record 35 of 50 in Set 11 | Progreso
# Processing Record 36 of 50 in Set 11 | Mongoumba
# Processing Record 37 of 50 in Set 11 | Saint-Ambroise
# Processing Record 38 of 50 in Set 11 | Kargasok
# Processing Record 39 of 50 in Set 11 | Zhezkazgan
# Processing Record 40 of 50 in Set 11 | Yangi Marg`ilon
# Processing Record 41 of 50 in Set 11 | Tateyama
# Processing Record 42 of 50 in Set 11 | Bundaberg
# Processing Record 43 of 50 in Set 11 | Ebéjico
# Processing Record 44 of 50 in Set 11 | Tepelenë
# Processing Record 45 of 50 in Set 11 | Tshikapa
# Tshikapa not found. Skipping...
# Processing Record 47 of 50 in Set 11 | Bulgan
# Processing Record 48 of 50 in Set 11 | Sahuaripa
# Processing Record 49 of 50 in Set 11 | Beitbridge
# Processing Record 50 of 50 in Set 11 | Sisimiut
# Processing Record 51 of 50 in Set 11 | Ketchikan
# Processing Record 2 of 50 in Set 12 | Kruglolesskoye
# Kruglolesskoye not found. Skipping...
# Kruglolesskoye not found. Skipping...
# Processing Record 5 of 50 in Set 12 | Kānker
# Processing Record 6 of 50 in Set 12 | Urbano Santos
# Processing Record 7 of 50 in Set 12 | Gornopravdinsk
# Processing Record 8 of 50 in Set 12 | Charcas
# Processing Record 9 of 50 in Set 12 | Wilmington
# Processing Record 10 of 50 in Set 12 | Zhangjiakou Shi Xuanhua Qu
# Processing Record 11 of 50 in Set 12 | Rome
# Processing Record 12 of 50 in Set 12 | Preobrazheniye
# Processing Record 13 of 50 in Set 12 | Mahajanga
# Processing Record 14 of 50 in Set 12 | Crawley
# Processing Record 15 of 50 in Set 12 | Port Blair
# Processing Record 16 of 50 in Set 12 | Buala
# Processing Record 17 of 50 in Set 12 | Betioky
# Processing Record 18 of 50 in Set 12 | Priozyornoye
# Processing Record 19 of 50 in Set 12 | Ust'-Omchug
# Processing Record 20 of 50 in Set 12 | Jertih
# Jertih not found. Skipping...
# Jertih not found. Skipping...
# Processing Record 23 of 50 in Set 12 | Mayya
# Processing Record 24 of 50 in Set 12 | Bako
# Processing Record 25 of 50 in Set 12 | Maragogi
# Processing Record 26 of 50 in Set 12 | Killybegs
# Processing Record 27 of 50 in Set 12 | Belyy Yar
# Processing Record 28 of 50 in Set 12 | Doka
# Processing Record 29 of 50 in Set 12 | Ol'ga
# Processing Record 30 of 50 in Set 12 | Constantine
# Constantine not found. Skipping...
# Constantine not found. Skipping...
# Processing Record 33 of 50 in Set 12 | Alexandria
# Processing Record 34 of 50 in Set 12 | Sistranda
# Processing Record 35 of 50 in Set 12 | Holbeach
# Processing Record 36 of 50 in Set 12 | Merauke
# Processing Record 37 of 50 in Set 12 | Neryungri
# Processing Record 38 of 50 in Set 12 | Okha
# Processing Record 39 of 50 in Set 12 | Marawi
# Processing Record 40 of 50 in Set 12 | Ozinki
# Processing Record 41 of 50 in Set 12 | Tarko-Sale
# Processing Record 42 of 50 in Set 12 | Zaranj
# Processing Record 43 of 50 in Set 12 | Kashgar
# Processing Record 44 of 50 in Set 12 | Zhuanghe
# Processing Record 45 of 50 in Set 12 | Enshi
# Processing Record 46 of 50 in Set 12 | Codrington
# Processing Record 47 of 50 in Set 12 | Locri
# Locri not found. Skipping...
# Processing Record 49 of 50 in Set 12 | Krasnoye-na-Volge
# Processing Record 50 of 50 in Set 12 | Ancud
# Processing Record 51 of 50 in Set 12 | Rājpīpla
# Processing Record 2 of 50 in Set 13 | Hamilton
# Processing Record 3 of 50 in Set 13 | Vrises
# Processing Record 4 of 50 in Set 13 | Torres
# Processing Record 5 of 50 in Set 13 | Louis Trichardt
# Processing Record 6 of 50 in Set 13 | Alta Floresta
# Processing Record 7 of 50 in Set 13 | Keelung
# Processing Record 8 of 50 in Set 13 | Mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        George Town      MY   5.41  100.34     80.60       100          20
# 1           Tasiilaq      GL  65.61  -37.64     41.00        88           5
# 2              Vaini      TO -21.20 -175.20     69.80        88          75
# 3          Mahébourg      MU -20.41   57.70     71.60        73          75
# 4  Saint Paul Harbor      US  57.79 -152.41     55.40        58          40
# 5             Kabalo      CD  -6.05   26.92     82.76        43          15
# 6            Rikitea      PF -23.12 -134.97     71.85        82          99
# 7            Qaanaaq      GL  77.48  -69.36     21.18        84          52
# 8             Jiwani      PK  25.05   61.74     83.30        73           0
# 9              Uren'      RU  57.46   45.79     53.06        78         100
#
#    Wind Speed       Description                 Date
# 0        0.43        light rain  2020-09-17 19:21:37
# 1        5.82         clear sky  2020-09-17 19:21:54
# 2       11.41     broken clouds  2020-09-17 19:21:55
# 3       14.99     broken clouds  2020-09-17 19:23:22
# 4       17.22  scattered clouds  2020-09-17 19:23:22
# 5        2.73        few clouds  2020-09-17 19:23:23
# 6       23.60   overcast clouds  2020-09-17 19:23:23
# 7        9.28     broken clouds  2020-09-17 19:23:23
# 8        6.98         clear sky  2020-09-17 19:23:23
# 9       13.22   overcast clouds  2020-09-17 19:23:24

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
